# %%
import matplotlib.pyplot as plt
import numpy as np
from skimage.io import imread

# %%
I = imread('/content/drive/MyDrive/IBM/Data Set/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/04de1246-ecfa-4d2c-bc2d-16b81b0bd364___JR_FrgE.S 2970.JPG')
J = imread('/content/drive/MyDrive/IBM/Data Set/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/05fb01a0-fd64-4b3d-a512-c0bda181811e___JR_FrgE.S 2889.JPG')

# %%
plt.figure()
plt.subplot(121), plt.imshow(I)
plt.subplot(122), plt.imshow(J)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(np.abs(I[:, :, 0].astype(float) - J[:, :, 0].astype(float)), cmap='gray')
plt.show()

# %%
d = imread('/content/drive/MyDrive/IBM/Data Set/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/05fb01a0-fd64-4b3d-a512-c0bda181811e___JR_FrgE.S 2889.JPG')
mask = imread('/content/drive/MyDrive/IBM/Data Set/Dataset Plant Disease/fruit-dataset/fruit-dataset/test/Apple___Black_rot/04de1246-ecfa-4d2c-bc2d-16b81b0bd364___JR_FrgE.S 2970.JPG')

print(np.amin(d), np.amax(d))
print(np.amin(mask), np.amax(mask))
# Out:
# 0 255
# 0 255

# %%
plt.figure(), plt.imshow(mask), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)

# %%
mask = mask[:, :, 0]

# %%
maskInv = np.zeros_like(mask)
maskInv[mask == 0] = 255
maskInv[mask == 255] = 0
plt.figure(), plt.imshow(maskInv, cmap='gray'), plt.show()
# Out:
# (<Figure size 432x288 with 1 Axes>,
# ...
#  None)
