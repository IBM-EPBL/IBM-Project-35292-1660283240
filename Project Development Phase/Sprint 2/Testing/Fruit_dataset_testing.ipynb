# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np

# %%
model = load_model (r"C:\IBM\Model\Model_For_Fruit_dataset\fruit.h5")

# %%
model

# %%
img = load_img(r'C:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Peach___Bacterial_spot\0a71ba91-8bde-4a91-84a9-bf950488f718___Rutg._Bact.S 2121.JPG',target_size = (128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1276F08BF40>

# %%
x=img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 122ms/step
# 'Peach___Bacterial_spot'

# %%
x
# Out:
# array([[[[ 92.,  92.,  92.],
#          [ 84.,  84.,  84.],
#          [ 78.,  78.,  78.],
#          ...,
#          [  9.,   5.,   6.],
#          [  8.,   4.,   5.],
#          [ 16.,  12.,  13.]],
#
#         [[ 74.,  74.,  74.],
#          [ 77.,  77.,  77.],
#          [ 83.,  83.,  83.],
#          ...,
#          [116., 114., 115.],
#          [ 74.,  72.,  73.],
#          [ 38.,  36.,  37.]],
#
#         [[ 86.,  86.,  86.],
#          [ 91.,  91.,  91.],
#          [ 82.,  82.,  82.],
#          ...,
#          [139., 143., 142.],
#          [138., 142., 141.],
#          [137., 141., 140.]],
#
#         ...,
#
#         [[125., 118., 125.],
#          [129., 122., 129.],
#          [132., 125., 132.],
#          ...,
#          [151., 148., 155.],
#          [151., 148., 155.],
#          [149., 146., 153.]],
#
#         [[126., 119., 126.],
#          [134., 127., 134.],
#          [134., 127., 134.],
#          ...,
#          [148., 145., 152.],
# ...

# %%
y
# Out:
# array([4], dtype=int64)
