# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import *
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.models import load_model
import numpy as np

# %%
model = load_model (r'C:\IBM\Model\Model_For_Vegetable_Dataset\vegetable.h5')

# %%
img = load_img(r'C:\IBM\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Pepper,_bell___Bacterial_spot\af404304-673d-4788-b622-104f2cb0e7be___JR_B.Spot 3257.JPG',target_size = (128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1DE203499D0>

# %%
x=img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___healthy','Potato___Late_blight','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
index[y[0]]
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 'Pepper,_bell___Bacterial_spot'

# %%
x
# Out:
# array([[[[169., 160., 179.],
#          [170., 161., 180.],
#          [166., 157., 176.],
#          ...,
#          [136., 126., 150.],
#          [155., 145., 169.],
#          [150., 140., 164.]],
#
#         [[172., 163., 182.],
#          [169., 160., 179.],
#          [176., 167., 186.],
#          ...,
#          [140., 130., 154.],
#          [157., 147., 171.],
#          [154., 144., 168.]],
#
#         [[175., 166., 185.],
#          [175., 166., 185.],
#          [184., 175., 194.],
#          ...,
#          [161., 151., 175.],
#          [173., 163., 187.],
#          [145., 135., 159.]],
#
#         ...,
#
#         [[170., 156., 173.],
#          [170., 156., 173.],
#          [233., 219., 236.],
#          ...,
#          [ 79.,  62.,  81.],
#          [105.,  88., 107.],
#          [138., 121., 140.]],
#
#         [[133., 120., 137.],
#          [145., 132., 149.],
#          [ 86.,  73.,  90.],
#          ...,
#          [114.,  97., 116.],
# ...

# %%
y
# Out:
# array([0], dtype=int64)
